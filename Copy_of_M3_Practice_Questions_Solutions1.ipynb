# %% [markdown]
# <a href="https://colab.research.google.com/github/rohit-kaveeshwar/rohit-kaveeshwar/blob/main/Copy_of_M3_Practice_Questions_Solutions1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ✅ Solutions: Module 3 (Lessons 1 & 2)

# %% [markdown]
# ## Q1: Basic Arithmetic Expression

# %%
a = 8
b = 3
c = 2
d = a * b + c / 2 - b % c
print("Result:", d)
# Out:
# Result: 24.0

# %% [markdown]
# ## Q2: Type Conversion Challenge

# %%
age = int(input("Enter your age: "))
year_to_100 = 2026 + (100 - age)
print(f"You will be 100 in {year_to_100}.")
# Out:
# Enter your age: 39
# You will be 100 in 2087.

# %% [markdown]
# ## Q3: Combine Strings and Numbers Safely

# %%
score = 93
print("Your score is: " + str(score))
# Out:
# Your score is: 93

# %% [markdown]
# ## Q4: Detect Data Type

# %%
value = input("Enter a value: ")
print("Type of input:", type(value))
# Out:
# Enter a value: 34
# Type of input: <class 'str'>

# %% [markdown]
# ## Q5: Valid or Invalid Integer

# %%
s = input("Enter a number: ")
try:
    num = int(s)
    print("Valid integer")
except ValueError:
    print("Invalid input")
# Out:
# Enter a number: 39.543
# Invalid input

# %% [markdown]
# ## Q6: Escape Character Use

# %%
print("Name:\tJohn\nAge:\t21\nAddress:\n123, Main Street\nCity")
# Out:
# Name:	John
# Age:	21
# Address:
# 123, Main Street
# City
